# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaDhuri/pandas/blob/main/pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dict = {
    'name' : ['harry', 'aditya', 'bana'],
    'city' : ['rampur', 'mumbai', 'goa'],
    'marks' : [45, 55, 65]
}

# %%
dict

# %%
df = pd.DataFrame(dict)

# %%
df

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends.csv', index=False)

# %%
df['marks'][0]=70

# %%
df

# %%
excel = pd.read_csv('friends.csv')

# %%
excel

# %%
excel['marks'][0]=70
# Out:
# <ipython-input-25-9a13f56dcdde>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   excel['marks'][0]=70

# %%
excel
# Out:
#      name    city  marks
# 0   harry  rampur     70
# 1  aditya  mumbai     55
# 2    bana     goa     65

# %%
excel.to_csv('friends.csv')

# %%
excel.index = ['first', 'second', 'third']

# %%
excel
# Out:
#           name    city  marks
# first    harry  rampur     70
# second  aditya  mumbai     55
# third     bana     goa     65

# %%
newdf = pd.DataFrame(np.random.rand(50,5), index=np.arange(50))

# %%
newdf
# Out:
#            0         1         2         3         4
# 0   0.315119  0.799689  0.716171  0.846184  0.940780
# 1   0.401515  0.975011  0.312219  0.092727  0.037932
# 2   0.180539  0.685626  0.151137  0.814493  0.109441
# 3   0.411886  0.115771  0.349634  0.313077  0.885299
# 4   0.580820  0.330173  0.901678  0.523018  0.416726
# 5   0.501022  0.541598  0.544821  0.974511  0.782488
# 6   0.647552  0.917041  0.446859  0.682841  0.356053
# 7   0.070653  0.068988  0.299668  0.375340  0.440563
# 8   0.578697  0.802121  0.816735  0.512625  0.745608
# 9   0.420645  0.870535  0.237103  0.956885  0.541242
# 10  0.510291  0.520292  0.805388  0.287718  0.028167
# 11  0.505855  0.361675  0.462331  0.797070  0.067902
# 12  0.921561  0.072981  0.247429  0.785263  0.174703
# 13  0.972683  0.430977  0.013653  0.968327  0.325937
# 14  0.618940  0.095379  0.678465  0.290847  0.545487
# 15  0.517996  0.804761  0.468092  0.678146  0.325979
# 16  0.431520  0.001823  0.111071  0.331906  0.573277
# ...

# %%
newdf[0][0]='ad'

# %%
newdf
# Out:
#            0         1         2         3         4
# 0         ad  0.799689  0.716171  0.846184  0.940780
# 1   0.401515  0.975011  0.312219  0.092727  0.037932
# 2   0.180539  0.685626  0.151137  0.814493  0.109441
# 3   0.411886  0.115771  0.349634  0.313077  0.885299
# 4    0.58082  0.330173  0.901678  0.523018  0.416726
# 5   0.501022  0.541598  0.544821  0.974511  0.782488
# 6   0.647552  0.917041  0.446859  0.682841  0.356053
# 7   0.070653  0.068988  0.299668  0.375340  0.440563
# 8   0.578697  0.802121  0.816735  0.512625  0.745608
# 9   0.420645  0.870535  0.237103  0.956885  0.541242
# 10  0.510291  0.520292  0.805388  0.287718  0.028167
# 11  0.505855  0.361675  0.462331  0.797070  0.067902
# 12  0.921561  0.072981  0.247429  0.785263  0.174703
# 13  0.972683  0.430977  0.013653  0.968327  0.325937
# 14   0.61894  0.095379  0.678465  0.290847  0.545487
# 15  0.517996  0.804761  0.468092  0.678146  0.325979
# 16   0.43152  0.001823  0.111071  0.331906  0.573277
# ...

# %%
ad = newdf.head()

# %%
ad.sort_index(axis=0, ascending=False)
# Out:
#           0         1         2         3         4
# 4   0.58082  0.330173  0.901678  0.523018  0.416726
# 3  0.411886  0.115771  0.349634  0.313077  0.885299
# 2  0.180539  0.685626  0.151137  0.814493  0.109441
# 1  0.401515  0.975011  0.312219  0.092727  0.037932
# 0        ad  0.799689  0.716171  0.846184  0.940780

# %%
ad.sort_index(axis=1, ascending = False)
# Out:
#           4         3         2         1         0
# 0  0.940780  0.846184  0.716171  0.799689        ad
# 1  0.037932  0.092727  0.312219  0.975011  0.401515
# 2  0.109441  0.814493  0.151137  0.685626  0.180539
# 3  0.885299  0.313077  0.349634  0.115771  0.411886
# 4  0.416726  0.523018  0.901678  0.330173   0.58082

# %%
ad.sort_index(ascending = False )
# Out:
#           0         1         2         3         4
# 4   0.58082  0.330173  0.901678  0.523018  0.416726
# 3  0.411886  0.115771  0.349634  0.313077  0.885299
# 2  0.180539  0.685626  0.151137  0.814493  0.109441
# 1  0.401515  0.975011  0.312219  0.092727  0.037932
# 0        ad  0.799689  0.716171  0.846184  0.940780

# %%
type(ad)
# Out:
# pandas.core.frame.DataFrame

# %%
type([0])
# Out:
# list

# %%
type([1])
# Out:
# list

# %%
ad.index= list('Abcde')

# %%
ad
# Out:
#           0         1         2         3         4
# A        ad  0.799689  0.716171  0.846184  0.940780
# b  0.401515  0.975011  0.312219  0.092727  0.037932
# c  0.180539  0.685626  0.151137  0.814493  0.109441
# d  0.411886  0.115771  0.349634  0.313077  0.885299
# e   0.58082  0.330173  0.901678  0.523018  0.416726

# %%
ad.columns=list('first')

# %%
ad
# Out:
#           f         i         r         s         t
# A        ad  0.799689  0.716171  0.846184  0.940780
# b  0.401515  0.975011  0.312219  0.092727  0.037932
# c  0.180539  0.685626  0.151137  0.814493  0.109441
# d  0.411886  0.115771  0.349634  0.313077  0.885299
# e   0.58082  0.330173  0.901678  0.523018  0.416726

# %%
ad.loc[0,0]=64
# Out:
# <ipython-input-69-535a211bf874>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ad.loc[0,0]=64

# %%
ad
# Out:
#           f         i         r         s         t     0
# A        ad  0.799689  0.716171  0.846184  0.940780   NaN
# b  0.401515  0.975011  0.312219  0.092727  0.037932   NaN
# c  0.180539  0.685626  0.151137  0.814493  0.109441   NaN
# d  0.411886  0.115771  0.349634  0.313077  0.885299   NaN
# e   0.58082  0.330173  0.901678  0.523018  0.416726   NaN
# 0       NaN       NaN       NaN       NaN       NaN  64.0

# %%
ad.drop(0,axis=1)
# Out:
#           f         i         r         s         t
# A        ad  0.799689  0.716171  0.846184  0.940780
# b  0.401515  0.975011  0.312219  0.092727  0.037932
# c  0.180539  0.685626  0.151137  0.814493  0.109441
# d  0.411886  0.115771  0.349634  0.313077  0.885299
# e   0.58082  0.330173  0.901678  0.523018  0.416726
# 0       NaN       NaN       NaN       NaN       NaN

# %%
ad=ad.drop(0,axis=1)

# %%
ad
# Out:
#           f         i         r         s         t
# A        ad  0.799689  0.716171  0.846184  0.940780
# b  0.401515  0.975011  0.312219  0.092727  0.037932
# c  0.180539  0.685626  0.151137  0.814493  0.109441
# d  0.411886  0.115771  0.349634  0.313077  0.885299
# e   0.58082  0.330173  0.901678  0.523018  0.416726

# %%
ad.loc['A','f']=0.3

# %%
ad
# Out:
#           f         i         r         s         t
# A       0.3  0.799689  0.716171  0.846184  0.940780
# b  0.401515  0.975011  0.312219  0.092727  0.037932
# c  0.180539  0.685626  0.151137  0.814493  0.109441
# d  0.411886  0.115771  0.349634  0.313077  0.885299
# e   0.58082  0.330173  0.901678  0.523018  0.416726
